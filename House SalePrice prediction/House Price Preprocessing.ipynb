# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
pd.pandas.set_option('display.max_columns',None)
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train_data.shape
# Out:
# (1460, 81)

# %%
#percent of each null values

columns = train_data.columns
for i in columns:
    print(i, (train_data[i].isnull().sum()*100/1462))
    if (train_data[i].isnull().sum()*100/1462)>20:
        print("************")
# Out:
# Id 0.0
# MSSubClass 0.0
# MSZoning 0.0
# LotFrontage 17.715458276333788
# LotArea 0.0
# Street 0.0
# Alley 93.63885088919288
# ************
# LotShape 0.0
# LandContour 0.0
# Utilities 0.0
# LotConfig 0.0
# LandSlope 0.0
# Neighborhood 0.0
# Condition1 0.0
# Condition2 0.0
# BldgType 0.0
# HouseStyle 0.0
# OverallQual 0.0
# OverallCond 0.0
# YearBuilt 0.0
# YearRemodAdd 0.0
# RoofStyle 0.0
# RoofMatl 0.0
# Exterior1st 0.0
# Exterior2nd 0.0
# MasVnrType 0.5471956224350205
# MasVnrArea 0.5471956224350205
# ExterQual 0.0
# ExterCond 0.0
# Foundation 0.0
# BsmtQual 2.53077975376197
# BsmtCond 2.53077975376197
# BsmtExposure 2.5991792065663475
# BsmtFinType1 2.53077975376197
# BsmtFinSF1 0.0
# BsmtFinType2 2.5991792065663475
# BsmtFinSF2 0.0
# BsmtUnfSF 0.0
# TotalBsmtSF 0.0
# Heating 0.0
# HeatingQC 0.0
# CentralAir 0.0
# Electrical 0.06839945280437756
# 1stFlrSF 0.0
# 2ndFlrSF 0.0
# LowQualFinSF 0.0
# GrLivArea 0.0
# BsmtFullBath 0.0
# BsmtHalfBath 0.0
# FullBath 0.0
# HalfBath 0.0
# ...

# %%
for feature in columns:
    data = train_data.copy()
    data[feature] = np.where(data[feature].isnull(), 0, 1)
    
    data.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.title(feature)
    plt.show()

# %%
print("Total Houses is : ", len(train_data['Id']))
# Out:
# Total Houses is :  1460

# %%
numerical_features = [feature for feature in data.columns if data[feature].dtypes != 'O']
print("No.of numerical features is : ", len(numerical_features))
# Out:
# No.of numerical features is :  38

# %%
train_data[numerical_features].head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
# 4          2000       350.0         655           0        490         1145
#
# ...

# %%
year_features = [feature for feature in numerical_features if 'Yr' in feature or 'Year' in feature] 
year_features
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_features:
    if feature != 'YrSold':
        data = train_data.copy()
        data[feature] = data['YrSold'] - data[feature]
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.title('SalePrice')
        plt.show()

# %%
discrete_features = [feature for feature in numerical_features if len(train_data[feature].unique()) < 25 and feature not in year_features] 
print("No.of Discrete features : ", len(discrete_features))
# Out:
# No.of Discrete features :  17

# %%
for feature in discrete_features:
    data_data = train_data.copy()
    data_data.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.xlabel(feature)
    plt.show()

# %%
categorical_features = [feature for feature in data.columns if data[feature].dtypes == 'O']
print("No.of categorical features is : ", len(continious_features))
# Out:
# No.of categorical features is :  17

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_features:
    data_data = train_data.copy()
    data_data.groupby(feature)['SalePrice'].mean().plot.bar()
    plt.xlabel(feature)
    plt.show()

# %%
continious_features = [feature for feature in numerical_features if feature not in discrete_features and feature not in year_features]
print("No.of continious features : ", len(continious_features))
# Out:
# No.of continious features :  17

# %%
continious_features
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
for feature in continious_features:
    data_data = train_data.copy()
    data_data.groupby(feature)['SalePrice'].mean().plot.hist(bins = 10)
    plt.xlabel(feature)
    plt.show()

# %%
for feature in continious_features:
    data_data = train_data.copy()
    data_data.groupby(feature)['SalePrice'].mean().plot.box()
    plt.xlabel(feature)
    plt.show()

# %%
for feature in continious_features:
    data = train_data.copy()
    data[feature] = np.log(data[feature])
    plt.scatter(data[feature], data['SalePrice'])
    plt.xlabel(feature)
    plt.ylabel('Sale Price')
    plt.show()
# Out:
# C:\Users\user\myanaconda3\lib\site-packages\pandas\core\arraylike.py:358: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
for i in categorical_features:
    print(i, (train_data[i].isnull().sum()*100/1462))
    if (train_data[i].isnull().sum()*100/1462)>20:
        print("************")
# Out:
# MSZoning 0.0
# Street 0.0
# Alley 93.63885088919288
# ************
# LotShape 0.0
# LandContour 0.0
# Utilities 0.0
# LotConfig 0.0
# LandSlope 0.0
# Neighborhood 0.0
# Condition1 0.0
# Condition2 0.0
# BldgType 0.0
# HouseStyle 0.0
# RoofStyle 0.0
# RoofMatl 0.0
# Exterior1st 0.0
# Exterior2nd 0.0
# MasVnrType 0.5471956224350205
# ExterQual 0.0
# ExterCond 0.0
# Foundation 0.0
# BsmtQual 2.53077975376197
# BsmtCond 2.53077975376197
# BsmtExposure 2.5991792065663475
# BsmtFinType1 2.53077975376197
# BsmtFinType2 2.5991792065663475
# Heating 0.0
# HeatingQC 0.0
# CentralAir 0.0
# Electrical 0.06839945280437756
# KitchenQual 0.0
# Functional 0.0
# FireplaceQu 47.19562243502052
# ************
# GarageType 5.540355677154583
# GarageFinish 5.540355677154583
# GarageQual 5.540355677154583
# GarageCond 5.540355677154583
# PavedDrive 0.0
# PoolQC 99.3844049247606
# ************
# Fence 80.64295485636114
# ************
# MiscFeature 96.16963064295486
# ************
# SaleType 0.0
# ...

# %%
train_data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...
